# %% [markdown]
# # Camera Access Exercises - Learn by Doing!
#
# In this notebook, you'll implement camera access functionality yourself using OpenCV.
# Each exercise provides skeleton code and points you to the right documentation.
#
# **Your mission**: Complete the `pass` statements with working code!
#
# ## 📚 Essential Resources:
# - [OpenCV Python Tutorials](https://docs.opencv.org/4.x/d6/d00/tutorial_py_root.html)
# - [VideoCapture Class Documentation](https://docs.opencv.org/4.x/d8/dfe/classcv_1_1VideoCapture.html)
# - [Camera and Video I/O Tutorial](https://docs.opencv.org/4.x/dd/d43/tutorial_py_video_display.html)
# - [OpenCV Python Reference](https://docs.opencv.org/4.x/d6/d00/tutorial_py_root.html)

# %%
# Import the libraries you'll need
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Exercise 1: Camera Detection
#
# **Goal**: Write a function that checks which cameras are available on your system.
#
# **Resources to check**:
# - [cv2.VideoCapture()](https://docs.opencv.org/4.x/d8/dfe/classcv_1_1VideoCapture.html#a57c0e81e83e60f36c83027dc2a188e80)
# - [VideoCapture.isOpened()](https://docs.opencv.org/4.x/d8/dfe/classcv_1_1VideoCapture.html#a9d2ca36789e7fcde7a4bf982c53d9522)
# - [VideoCapture.read()](https://docs.opencv.org/4.x/d8/dfe/classcv_1_1VideoCapture.html#a473055e77dd7faa4d26d686226b292c1)
#
# **Hints**:
# - Try camera indices 0, 1, 2, etc.
# - Use `cap.isOpened()` to check if camera opened successfully
# - Use `cap.read()` to test if you can actually get frames
# - Don't forget to `cap.release()` each camera you test!

# %%
def find_available_cameras(max_cameras=5):
    """
    Find all available cameras on the system.
    
    Args:
        max_cameras (int): Maximum number of camera indices to check
    
    Returns:
        list: List of working camera indices
    """
    available_cameras = []
    
    print("🔍 Searching for cameras...")
    
    for camera_index in range(max_cameras):
        # TODO: Create a VideoCapture object for this camera index
        # Hint: Look up cv2.VideoCapture() in the documentation
        pass
        
        # TODO: Check if the camera opened successfully
        # Hint: VideoCapture objects have a method to check if they're open
        if False:  # Replace False with your condition
            # TODO: Try to read a frame to make sure camera actually works
            # Hint: VideoCapture objects have a read() method that returns success status and frame
            pass
            
            # TODO: If frame was read successfully, add camera to available list
            if False:  # Replace False with your condition
                available_cameras.append(camera_index)
                print(f"✅ Camera {camera_index}: Working")
            else:
                print(f"❌ Camera {camera_index}: Cannot read frames")
        else:
            print(f"❌ Camera {camera_index}: Cannot open")
        
        # TODO: Release the camera resource
        # Hint: VideoCapture objects need to be released when done
        pass
    
    print(f"\n📷 Found {len(available_cameras)} working cameras: {available_cameras}")
    return available_cameras

# Test your function
cameras = find_available_cameras()
CAMERA_INDEX = cameras[0] if cameras else 0

# %% [markdown]
# ## Exercise 2: Camera Information
#
# **Goal**: Get detailed information about your camera's capabilities.
#
# **Resources to check**:
# - [VideoCapture.get()](https://docs.opencv.org/4.x/d8/dfe/classcv_1_1VideoCapture.html#aa6480e6972ef4c00d74814ec841a2939)
# - [VideoCapture Properties](https://docs.opencv.org/4.x/d4/d15/group__videoio__flags__base.html#gaeb8dd9c89c10a5c63c139bf7c4f5704d)
#
# **Key Properties to explore**:
# - `cv2.CAP_PROP_FRAME_WIDTH`
# - `cv2.CAP_PROP_FRAME_HEIGHT`
# - `cv2.CAP_PROP_FPS`
# - `cv2.CAP_PROP_BRIGHTNESS`

# %%
def get_camera_properties(camera_index=0):
    """
    Get and display camera properties.
    
    Args:
        camera_index (int): Index of camera to examine
    """
    # TODO: Open the camera
    # Hint: Use the VideoCapture class with the camera index
    pass
    
    # TODO: Check if camera opened successfully
    if False:  # Replace with your condition
        print(f"❌ Cannot open camera {camera_index}")
        return
    
    print(f"📷 Camera {camera_index} Properties:")
    
    # TODO: Get the frame width
    # Hint: VideoCapture has a get() method that takes property constants like CAP_PROP_FRAME_WIDTH
    width = 0  # Replace with your code
    
    # TODO: Get the frame height  
    # Hint: Similar to width, but use the height property constant
    height = 0  # Replace with your code
    
    # TODO: Get the frames per second
    # Hint: Use the FPS property constant with the get() method
    fps = 0  # Replace with your code
    
    print(f"  Resolution: {width}x{height}")
    print(f"  FPS: {fps}")
    
    # TODO: Try to get a test frame and show its properties
    # Hint: Use the read() method to capture one frame
    pass
    
    # TODO: If frame was captured successfully, print frame info
    if False:  # Replace with your condition
        print(f"  Frame shape: {frame.shape}")
        print(f"  Color channels: {len(frame.shape)}")
    
    # TODO: Release the camera
    pass

# Test your function
if cameras:
    get_camera_properties(CAMERA_INDEX)
else:
    print("⚠️ No cameras available for testing")

# %% [markdown]
# ## Exercise 3: Capture and Save a Photo
#
# **Goal**: Capture a single photo from your camera and save it to disk.
#
# **Resources to check**:
# - [cv2.imwrite()](https://docs.opencv.org/4.x/d4/da8/group__imgcodecs.html#gabbc7ef1aa2edfaa87772f1202d67e0ce)
# - [cv2.cvtColor()](https://docs.opencv.org/4.x/d8/d01/group__imgproc__color__conversions.html#ga397ae87e1288a81d2363b61574eb8cab)
# - [Color Conversion Codes](https://docs.opencv.org/4.x/d8/d01/group__imgproc__color__conversions.html#ga4e0972be5de079fed4e3a10e24ef5ef0)
#
# **Hints**:
# - OpenCV uses BGR color format, matplotlib uses RGB
# - Use `cv2.COLOR_BGR2RGB` for displaying with matplotlib
# - Use `cv2.imwrite()` to save images

# %%
def capture_photo(camera_index=0, filename="captured_photo.jpg", countdown=3):
    """
    Capture a photo with countdown and save it.
    
    Args:
        camera_index (int): Camera to use
        filename (str): Where to save the photo
        countdown (int): Countdown seconds before capture
    """
    # TODO: Open the camera
    pass
    
    # TODO: Check if camera opened
    if False:  # Replace with your condition
        print(f"❌ Cannot open camera {camera_index}")
        return None
    
    # Countdown
    print(f"📸 Taking photo in {countdown} seconds...")
    for i in range(countdown, 0, -1):
        print(f"  {i}...")
        time.sleep(1)
    
    print("📷 *CLICK*")
    
    # TODO: Capture a frame
    # Hint: Use the camera's read() method to get the current frame
    pass
    
    # TODO: Check if frame was captured successfully
    if False:  # Replace with your condition
        # TODO: Save the frame to disk
        # Hint: OpenCV has a function to write images to files
        pass
        
        print(f"✅ Photo saved as {filename}")
        
        # TODO: Convert BGR to RGB for display
        # Hint: Use cvtColor() to convert between color spaces
        pass
        
        # Display the photo
        plt.figure(figsize=(10, 8))
        # TODO: Show the RGB image with matplotlib
        # Hint: matplotlib has an imshow() function
        pass
        plt.title('Captured Photo')
        plt.axis('off')
        plt.show()
        
        # TODO: Release camera and return the frame
        pass
        return frame
    else:
        print("❌ Failed to capture photo")
        # TODO: Release camera
        pass
        return None

# Test your function
if cameras:
    photo = capture_photo(CAMERA_INDEX, "../data/my_photo.jpg")
else:
    print("⚠️ No cameras available for photo capture")

# %% [markdown]
# ## Exercise 4: Real-time Camera Feed
#
# **Goal**: Create a live camera feed window that updates in real-time.
#
# **Resources to check**:
# - [cv2.imshow()](https://docs.opencv.org/4.x/d7/dfc/group__highgui.html#ga453d42fe4cb60e5723281a89973ee563)
# - [cv2.waitKey()](https://docs.opencv.org/4.x/d7/dfc/group__highgui.html#ga5628525ad33f52eab17feebcfba38bd7)
# - [cv2.destroyAllWindows()](https://docs.opencv.org/4.x/d7/dfc/group__highgui.html#ga6b7fc1c1a8960438156912027b38f481)
#
# **Important**: This creates a window that may not work in all environments (like dev containers).
# If you don't see a window, that's normal - the code structure is what matters!

# %%
def live_camera_feed(camera_index=0, duration=10):
    """
    Display live camera feed for a specified duration.
    
    Args:
        camera_index (int): Camera to use
        duration (int): How long to run (seconds)
    """
    print(f"📹 Starting live camera feed for {duration} seconds...")
    print("   Press 'q' to quit early")
    print("   Press 's' to save current frame")
    
    # TODO: Open camera
    # Hint: Use VideoCapture with the camera index
    pass
    
    # TODO: Check if camera opened
    if False:  # Replace with your condition
        print(f"❌ Cannot open camera {camera_index}")
        return
    
    start_time = time.time()
    frame_count = 0
    
    while True:
        # TODO: Read frame from camera
        # Hint: VideoCapture's read() method returns success flag and frame
        pass  
        
        # TODO: Check if frame was read successfully
        if False:  # Replace with your condition
            print("❌ Cannot read frame")
            break
        
        frame_count += 1
        elapsed = time.time() - start_time
        
        # Add some text to the frame (optional)
        cv2.putText(frame, f'Frame: {frame_count}', (10, 30), 
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        cv2.putText(frame, f'Time: {elapsed:.1f}s', (10, 70), 
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
        # TODO: Display the frame in a window
        # Hint: OpenCV has an imshow() function for displaying images in windows
        pass
        
        # TODO: Wait for key press (1ms timeout)
        # Hint: OpenCV's waitKey() function waits for key press and returns the key code
        key = 0  # Replace with your code
        
        # Check for quit condition
        if key == ord('q') or elapsed > duration:
            break
        elif key == ord('s'):
            # Save current frame
            save_name = f"../data/live_frame_{int(time.time())}.jpg"
            cv2.imwrite(save_name, frame)
            print(f"💾 Saved frame as {save_name}")
    
    # TODO: Release camera and close windows
    # Hint: VideoCapture needs release() and OpenCV windows need destroyAllWindows()
    pass
    
    print(f"✅ Live feed ended. Processed {frame_count} frames")

# Test your function (uncomment to try)
if cameras:
    print("📝 Uncomment the line below to test live camera feed:")
    print("# live_camera_feed(CAMERA_INDEX, duration=15)")
    # live_camera_feed(CAMERA_INDEX, duration=15)
else:
    print("⚠️ No cameras available for live feed test")

# %% [markdown]
# ## Exercise 5: Basic Image Processing on Camera Feed
#
# **Goal**: Apply simple image processing effects to live camera feed.
#
# **Resources to check**:
# - [cv2.cvtColor() Color Conversions](https://docs.opencv.org/4.x/d8/d01/group__imgproc__color__conversions.html)
# - [cv2.GaussianBlur()](https://docs.opencv.org/4.x/d4/d86/group__imgproc__filter.html#gaabe8c836e97159a9193fb0b11ac52cf1)
# - [cv2.Canny() Edge Detection](https://docs.opencv.org/4.x/dd/d1a/group__imgproc__feature.html#ga04723e007ed888ddf11d9ba04e2232de)
# - [cv2.inRange() Color Filtering](https://docs.opencv.org/4.x/d2/de8/group__core__array.html#ga48af0ab51e36436c5d04340e036ce981)
#
# **Effects to implement**:
# 1. Grayscale conversion
# 2. Gaussian blur
# 3. Edge detection
# 4. Color filtering (isolate specific colors)

# %%
def process_camera_feed(camera_index=0, duration=20):
    """
    Apply real-time image processing effects to camera feed.
    
    Args:
        camera_index (int): Camera to use
        duration (int): How long to run (seconds)
    """
    print(f"🎨 Starting real-time image processing for {duration} seconds...")
    print("   Press 'q' to quit")
    print("   Press '1' for Original, '2' for Grayscale, '3' for Blur")
    print("   Press '4' for Edge Detection, '5' for Red Object Filter")
    
    # TODO: Open camera
    pass
    
    # TODO: Check if camera opened
    if False:  # Replace with your condition
        print(f"❌ Cannot open camera {camera_index}")
        return
    
    start_time = time.time()
    current_effect = 1  # Start with original
    
    while True:
        # TODO: Read frame
        pass
        
        # TODO: Check if frame read successfully
        if False:  # Replace with your condition
            break
        
        # Apply different effects based on current_effect
        if current_effect == 1:
            processed = frame.copy()  # Original
            effect_name = "Original"
            
        elif current_effect == 2:
            # TODO: Convert to grayscale and back to BGR for display
            # Hint: Convert to grayscale, then convert back to 3-channel for consistent display
            processed = frame.copy()  # Replace this line
            effect_name = "Grayscale"
            
        elif current_effect == 3:
            # TODO: Apply Gaussian blur
            # Hint: Use GaussianBlur with appropriate kernel size
            processed = frame.copy()  # Replace this line
            effect_name = "Blur"
            
        elif current_effect == 4:
            # TODO: Apply Canny edge detection
            # Hint: Convert to grayscale first, apply Canny, then convert back to BGR
            processed = frame.copy()  # Replace this line
            effect_name = "Edges"
            
        elif current_effect == 5:
            # TODO: Filter red objects using HSV color space
            # Hint: Convert to HSV, create mask for red colors, apply mask to original
            # Note: Red wraps around in HSV (0-10 and 170-180 hue ranges)
            processed = frame.copy()  # Replace this line
            effect_name = "Red Filter"
        
        # Add effect name to image
        cv2.putText(processed, f'Effect: {effect_name}', (10, 30),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
        # TODO: Display the processed frame
        pass
        
        # TODO: Handle key presses
        key = 0  # Replace with waitkey code
        
        if key == ord('q') or time.time() - start_time > duration:
            break
        elif key in [ord('1'), ord('2'), ord('3'), ord('4'), ord('5')]:
            current_effect = int(chr(key))
            print(f"Switched to effect: {current_effect}")
    
    # TODO: Clean up
    pass
    print("✅ Processing demo completed")

# Test your function (uncomment to try)
if cameras:
    print("📝 Uncomment the line below to test image processing:")
    print("# process_camera_feed(CAMERA_INDEX, duration=30)")
    # process_camera_feed(CAMERA_INDEX, duration=30)
else:
    print("⚠️ No cameras available for processing test")

# %% [markdown]
# ## Challenge Exercises 🏆
#
# Ready for more? Try these advanced challenges:
#
# ### Challenge 1: Motion Detection
# Create a motion detector that:
# - Captures a background frame
# - Compares new frames to background
# - Highlights areas where motion is detected
# - Counts motion events
#
# **Resources**:
# - [cv2.absdiff()](https://docs.opencv.org/4.x/d2/de8/group__core__array.html#ga6fef31bc8c4071cbc114a758a2b79c14)
# - [cv2.threshold()](https://docs.opencv.org/4.x/d7/d1b/group__imgproc__misc.html#gae8a4a146d1ca78c626a53577199e9c57)
# - [cv2.findContours()](https://docs.opencv.org/4.x/d3/dc0/group__imgproc__shape.html#gadf1ad6a0b82947fa1fe3c3d497f260e0)
#
# ### Challenge 2: Face Detection
# Implement face detection using Haar cascades:
# - Load a pre-trained face cascade
# - Detect faces in real-time
# - Draw rectangles around detected faces
# - Count the number of faces
#
# **Resources**:
# - [cv2.CascadeClassifier](https://docs.opencv.org/4.x/db/d28/tutorial_cascade_classifier.html)
# - [Haar Cascade Tutorial](https://docs.opencv.org/4.x/db/d28/tutorial_cascade_classifier.html)
#
# ### Challenge 3: Color Object Tracker
# Build an object tracker that:
# - Lets user click to select a color
# - Tracks objects of that color
# - Shows the center point and trajectory
# - Handles multiple objects
#
# **Resources**:
# - [Mouse Callback Events](https://docs.opencv.org/4.x/db/d5b/tutorial_py_mouse_handling.html)
# - [cv2.setMouseCallback()](https://docs.opencv.org/4.x/d7/dfc/group__highgui.html#ga89e7806b0a616f6f1d502bd8c183ad3e)
# - [cv2.moments()](https://docs.opencv.org/4.x/d3/dc0/group__imgproc__shape.html#ga556a180f43cab22649c23ada36a8a139)

# %%
# Challenge implementations go here!
# Pick one or more challenges and implement them

def motion_detector(camera_index=0):
    """
    Challenge 1: Implement motion detection
    
    Your task:
    1. Capture a background frame
    2. Compare subsequent frames to background
    3. Highlight motion areas
    4. Count motion events
    """
    # TODO: Your implementation here
    print("🎯 Challenge 1: Motion Detection")
    print("Implement me!")
    pass

def face_detector(camera_index=0):
    """
    Challenge 2: Implement face detection
    
    Your task:
    1. Load haar cascade for face detection
    2. Detect faces in camera feed
    3. Draw rectangles around faces
    4. Count faces detected
    """
    # TODO: Your implementation here
    print("🎯 Challenge 2: Face Detection")
    print("Implement me!")
    pass

def color_object_tracker(camera_index=0):
    """
    Challenge 3: Implement color object tracking
    
    Your task:
    1. Let user click to select color
    2. Track objects of selected color
    3. Show center points and trajectories
    4. Handle multiple objects
    """
    # TODO: Your implementation here
    print("🎯 Challenge 3: Color Object Tracker")
    print("Implement me!")
    pass

print("🏆 Challenge exercises ready!")
print("Choose a challenge and start implementing:")
print("• motion_detector(CAMERA_INDEX)")
print("• face_detector(CAMERA_INDEX)")
print("• color_object_tracker(CAMERA_INDEX)")

# %% [markdown]
# ## 🎓 Learning Checklist
#
# By completing these exercises, you should be able to:
#
# **Basic Camera Operations:**
# - ✅ Detect available cameras on your system
# - ✅ Open and configure camera settings
# - ✅ Capture single images from camera
# - ✅ Create real-time camera feeds
# - ✅ Properly release camera resources
#
# **Image Processing:**
# - ✅ Convert between color spaces (BGR ↔ RGB ↔ HSV ↔ Grayscale)
# - ✅ Apply basic filters (blur, edge detection)
# - ✅ Perform color-based filtering and object isolation
# - ✅ Handle real-time image processing pipelines
#
# **Error Handling & Best Practices:**
# - ✅ Check camera availability before use
# - ✅ Handle camera access failures gracefully
# - ✅ Implement proper resource cleanup
# - ✅ Create user-friendly error messages
#
# ## 📚 Next Steps
#
# Now that you've mastered camera basics, you're ready for:
# - **Object Detection**: Using YOLO, Haar cascades, or DNN models
# - **Feature Detection**: SIFT, SURF, ORB keypoints and descriptors
# - **Motion Analysis**: Optical flow and tracking algorithms
# - **3D Vision**: Stereo cameras and depth estimation
# - **Machine Learning**: Integration with TensorFlow/PyTorch models
#
# **Great job completing the camera exercises!** 🎉
#
# ---
#
# ### 💡 Debugging Tips
# - If camera doesn't work: Check permissions, try different indices, close other camera apps
# - If windows don't appear: Normal in some environments (dev containers) - focus on the code logic
# - If processing is slow: Reduce resolution, optimize algorithms, or limit frame rate
# - If colors look wrong: Check BGR vs RGB conversion for display functions
